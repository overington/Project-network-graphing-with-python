# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx


import numpy as np
from numpy.random import randint as r

# Load the CSV
df = pd.read_csv('data/London.csv')

# %%
rf_parsed = pd.DataFrame()

# Make a set of all the junctions; coming from the start junctions and end junctions.
junctions = set(df.EndJunction.values)
junctions = set(df.StartJunction.values)

# %%
G = nx.Graph()


# G.add_nodes_from(df['road_id'])
G.add_nodes_from(junctions)
G.add_edges_from(df[['StartJunction','EndJunction']].values, pos=list(df[['Easting', 'Northing']].values))


nx.draw_shell(G)
# Out:
# /Users/samuel/.virtualenvs/redoptima/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
for key, val in junctions:
    print('{} : {}'.format(key, val))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-1d37aa878ac5> in <module>
# ----> 1 for key, val in junctions:
#       2     print('{} : {}'.format(key, val))
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
rds = list(junctions)[r(0, 30)::120]
print(rds)

road_connections_list = [
    rds[0:2],
    rds[2:4],
    rds[4:6],
    rds[6:],
]

for i in range(10):
    tmp = rds[r(3)::r(1,len(rds)) ]
    print(tmp)

road_connections = dict()
for i, road in enumerate(rds):
    if i < len(road_connections):
        road_connections[road] = road_connections_list[i]
    else:
        road_connections[road] = rds[r(3)::r(1,len(rds)) ]

print(road_connections)

# juncs = [road_name for road_name, road_juncts in dict_of_roads]
# egs = [np.random.random_integers(0,9) for i in juncs]
G = nx.Graph()
G.add_nodes_from(rds)
for road, connection in road_connections:
#     print('tmp: ',tmp)
    print("road: ", road)
    print("connection: ", connection)
    G.add_edges_from([road,connections])
nx.draw_circular(G)
# Out:
# [nan, 'Elephant and Castle', 'A109', 'A2001', 'A302', 'A307', 'A5 W Hendon Broadway meets A504 Herbert Road']
# ['Elephant and Castle', 'A2001', 'A307']
# [nan, 'Elephant and Castle', 'A109', 'A2001', 'A302', 'A307', 'A5 W Hendon Broadway meets A504 Herbert Road']
# [nan, 'A109', 'A302', 'A5 W Hendon Broadway meets A504 Herbert Road']
# ['Elephant and Castle', 'A5 W Hendon Broadway meets A504 Herbert Road']
# ['Elephant and Castle', 'A302']
# [nan, 'A2001', 'A5 W Hendon Broadway meets A504 Herbert Road']
# [nan, 'A2001', 'A5 W Hendon Broadway meets A504 Herbert Road']
# ['A109', 'A307']
# ['A109', 'A302', 'A5 W Hendon Broadway meets A504 Herbert Road']
# ['Elephant and Castle', 'A109', 'A2001', 'A302', 'A307', 'A5 W Hendon Broadway meets A504 Herbert Road']
# ...
